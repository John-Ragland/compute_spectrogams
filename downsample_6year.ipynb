# %%
import pickle
import ooipy
import spec_tools
import numpy as np
from matplotlib import pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %%
# Load 6 year spectrogram

file_dir = '/Volumes/Ocean_Acoustics/Spectrograms/Southern_Hydrate/6_year_spectrogram.pkl'
with open(file_dir, 'rb') as f:
    spec = pickle.load(f)

# %%
plt.plot(spec.time)

# %%
import pandas as pd
spec_times = []
year = 2015
start = 100

time = pd.Timestamp(f'{year}-01-01') + pd.Timedelta(hours=start)
spec_times.append(time)

print(spec_times)
# Out:
# [Timestamp('2015-01-05 04:00:00')]

# %%
fig = plt.figure(figsize=(15,5))
plt.imshow(spec.values.T, cmap='jet', vmin=20, vmax=100, origin='lower')
plt.colorbar()

# %% [markdown]
# ## Debugging Southern Hydrate Location

# %%
hydrophone = 'Southern_Hydrate'
year=2015

spec_dir = f'/Volumes/Ocean_Acoustics/Spectrograms/{hydrophone}/{year}/'
time, freq, values = spec_tools.merge(1000, 1100, spec_dir)

spec = ooipy.hydrophone.basic.Spectrogram(time, freq, values)
# Out:
# 100%|██████████| 100/100 [00:03<00:00, 25.16it/s]

# %%
np.linspace(0,100,spec.values.shape[1])
# Out:
# array([  0.00000000e+00,   4.88281250e-02,   9.76562500e-02, ...,
#          9.99023438e+01,   9.99511719e+01,   1.00000000e+02])
