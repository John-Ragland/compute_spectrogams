# %% [markdown]
# # Look at Month-long PSD
# read from pre-computed spectrogram

# %%
import ooipy
import numpy as np
import Noise_Interferometry
import spec_tools
from matplotlib import pyplot as plt
import pickle

# %load_ext autoreload
# %autoreload 2

# %%
year = 2017
month = 6
node = 'Central_Caldera'
month_hours = spec_tools.get_hour_index_array(year%4==0)
spec_start, spec_end = month_hours[month-1], month_hours[month]
spec_dir = f'/Volumes/Ocean_Acoustics/Spectrograms/{node}/{year}/'

times, freq, values = spec_tools.merge(spec_start, spec_end, spec_dir)

values = np.ma.masked_array(values, np.isnan(values))
# Out:
# [==============================                                          ]  41%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-f7956bb596e2> in <module>
#       6 spec_dir = f'/Volumes/Ocean_Acoustics/Spectrograms/{node}/{year}/'
#       7
# ----> 8 times, freq, values = spec_tools.merge(spec_start, spec_end, spec_dir)
#       9
#      10 values = np.ma.masked_array(values, np.isnan(values))
#
# ~/Code/ocean_acoustics/compute_spectrograms/spec_tools.py in merge(spec_start, spec_end, spec_dir, verbose)
#     108             times = np.asarray(time)
#     109         else:
# --> 110             values = np.vstack((values,spec.values))
#     111             times = np.hstack((times,np.asarray(time)))
#     112         if verbose: bar.update(k- spec_start)
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# ~/opt/anaconda3/envs/ooi/lib/python3.7/site-packages/numpy/core/shape_base.py in vstack(tup)
#     281     if not isinstance(arrs, list):
#     282         arrs = [arrs]
# --> 283     return _nx.concatenate(arrs, 0)
#     284
#     285
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# inputs that work
print(spec_start, spec_end, spec_dir)
# Out:
# 3624 4344 /Volumes/Ocean_Acoustics/Spectrograms/Central/2017/

# %%
PSD = np.mean(values, axis=0)

# %%
fig = plt.figure(figsize=(7,5))
plt.rcParams['font.size'] = '14'
plt.plot(freq, PSD)
plt.grid()
plt.ylabel('Power (dB)')
plt.xlabel('frequency (Hz)')
plt.grid()
plt.xlim([0, 100])
# Out:
# (0.0, 100.0)

# %%
values
# Out:
# masked_array(data =
#  [[-- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#   -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#   -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#   -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#   -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --]],
#              mask =
#  [[ True  True  True ...,  True  True  True]],
#        fill_value = 1e+20)

# %% [markdown]
# ## Loading yearlong figure

# %%
filename = '/Volumes/Ocean_Acoustics/Spectrograms/Central_Caldera/6_year_spectrogram.pkl'

with open(filename, 'rb') as f:
    spec = pickle.load(f)

values = np.ma.masked_array(spec.values, np.isnan(spec.values))

# %%
yearlong_psd = np.mean(values, axis=0)

# %%
plt.plot(spec.freq, yearlong_psd)
plt.ylabel('dB')
plt.xlabel('Frequency (Hz)')
plt.title('6 Year Average PSD - Eastern Caldera')

print(spec.freq[np.argmin(yearlong_psd[1:1000])])
# Out:
# 5.859375

# %% [markdown]
# ## Playing with monthlong script

# %%
fig, ax = spec_tools.monthly_psds([2017], [6], ['Central_Caldera'], savefig=False)
# Out:
# [                                                                        ] N/A%Merging for Central_Caldera, 2017-6...
#
# [======================================================================= ]  98%

# %%
plt.sca(ax)
plt.show()
ax.set_xlim([0, 30])
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-582a778f6e7e> in <module>
# ----> 1 plt.sca(ax)
#       2 plt.show()
#       3 ax.set_xlim([0, 30])
#       4 plt.grid()
#
# ~/opt/anaconda3/envs/ooi/lib/python3.7/site-packages/matplotlib/pyplot.py in sca(ax)
#     856             m.canvas.figure.sca(ax)
#     857             return
# --> 858     raise ValueError("Axes instance argument was not found in a figure")
#     859
#     860
#
# ValueError: Axes instance argument was not found in a figure
