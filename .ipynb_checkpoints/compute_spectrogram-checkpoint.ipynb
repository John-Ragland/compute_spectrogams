# %%
import os
import sys
cwd = os.getcwd()
ooipy_dir = os.path.dirname(cwd) + '/ooipy'
sys.path.append(ooipy_dir)
from matplotlib import pyplot as plt
import datetime
import numpy as np
from obspy import read,Stream, Trace
from obspy.core import UTCDateTime

from obspy import read
import pickle
import scipy
from gwpy.timeseries import TimeSeries
import seaborn as sns

from ooipy.request import hydrophone_request
from ooipy.hydrophone import basic
import gwpy

import plotly.express as px
import progressbar
from scipy import signal


# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Merging All Spectrograms

# %%
import progressbar
spec_start = 0
spec_end = 100


bar = progressbar.ProgressBar(maxval=spec_end-spec_start, \
    widgets=[progressbar.Bar('=', '[', ']'), ' ', progressbar.Percentage()])
bar.start()

time = []
for k in range(spec_start,spec_end):
    file_path = f"/Volumes/John's Passport/Spectrograms/Eastern_Caldera_2017/spectrogram{k:03}.pkl"
    try:
        with open(file_path, 'rb') as f:
            spec = pickle.load(f)
        spec.time
    except:

        continue
    time_UTC = spec.time

    if k == spec_start:
        freq = spec.freq
    for n in range(len(time_UTC)):
        if n == 0:
            if type(time_UTC[n]) == datetime.datetime:
                time = [time_UTC[n]]
            else:
                time = [time_UTC[n].datetime]
        else:
            if type(time_UTC[n]) == datetime.datetime:
                time.append(time_UTC[n])
            else:
                time.append(time_UTC[n].datetime)
    if k == spec_start:
        values = spec.values
        times = np.asarray(time)
    else:
        values = np.vstack((values,spec.values))
        times = np.hstack((times,np.asarray(time)))
    bar.update(k- spec_start)
# Out:
# [======================================================================= ]  99%

# %% [markdown]
# ### Write to .mat File

# %%
# Convert times to string
times_str = []
for k in range(len(times)):
    times_str.append(times[k].strftime("%d-%b-%Y %H:%M:%S"))

# Write Time and Frequency Arrays to .mat file
mdic = {"freq": freq, "times_str": times_str, "values":values}
scipy.io.savemat('Spectrogram.mat',mdic)

# %%
print(values.shape)
print(times.shape)
print(freq.shape)

print(values)
# Out:
# (5851, 2049)
# (5851,)
# (2049,)
# [[ 36.86414     36.27105211  41.77616668 ...,   8.33005749
#     8.54673298   1.25115421]
#  [ 35.65653834  33.12397504  36.31655365 ...,   8.66131423
#     6.56377432   4.9953055 ]
#  [ 38.64114719  35.33667621  37.78517972 ...,   7.16600285
#     7.02291686   4.89493417]
#  ...,
#  [ 42.89584754  38.86232346  37.26109944 ...,   3.32612105
#     9.43813865   3.85284356]
#  [ 31.64958831  33.4954823   34.19600302 ...,  12.80161742
#     9.87242536   2.68180025]
#  [ 40.94791164  35.44152748  36.36798476 ...,  10.82248791
#    12.05877232   5.75758085]]

# %%
# Generate alternate time variables
from datetime import timedelta

times_delta = []
times_new = np.zeros((len(times),1))
for k in range(len(times)):
    times_delta.append(times[k]-times[0])
    
    times_new[k] = times_delta[k].days*24 + times_delta[k].seconds/3600


times_new = np.squeeze(times_new)

print(np.shape(times_new))
# Out:
# (5961,)

# %%
# Create Spectrogram Object

spec_full = basic.Spectrogram(times, freq, values)

# %%
#fig = px.imshow(values.T, origin='lower', x=times, y=freq, labels = {'color':'dB re 1µ Pa^2/Hz'})
xlim = [datetime.datetime(2017,7,16,0,0,0), datetime.datetime(2017,7,17,0,0,0)]
spec_full.plot(xlabel_rot=30,res_reduction_time=10, fmax=100, filename='Southern_Hydrate_July_zoomed',save_spec=False, vmax=80, plot_spec=True)

# %% [markdown]
# # Generate Month Spectrograms

# %%
import spec_tools

spec_dir = f"/Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017"

spec = spec_tools.merge(0,100, spec_dir)
# Out:
# [                                                                        ] N/A%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram000.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram001.pkl
# [==                                                                      ]   4%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram002.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram003.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram004.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram005.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram006.pkl
# [=======                                                                 ]  11%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram007.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram008.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram009.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram010.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram011.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram012.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram013.pkl
# [===========                                                             ]  16%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram014.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram015.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram016.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram017.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram018.pkl
# [===============                                                         ]  22%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram019.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram020.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram021.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram022.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram023.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram024.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram025.pkl
# [===================                                                     ]  27%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram026.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram027.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram028.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram029.pkl
# [=======================                                                 ]  33%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram030.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram031.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram032.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram033.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram034.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram035.pkl
# [===========================                                             ]  38%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram036.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram037.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram038.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram039.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram040.pkl
# [=============================                                           ]  41%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram041.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram042.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram043.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram044.pkl
# [=================================                                       ]  47%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram045.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram046.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram047.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram048.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram049.pkl
# [====================================                                    ]  51%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram050.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram051.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram052.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram053.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram054.pkl
# [=========================================                               ]  57%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram055.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram056.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram057.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram058.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram059.pkl
# [===========================================                             ]  61%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram060.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram061.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram062.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram063.pkl
# [==============================================                          ]  65%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram064.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram065.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram066.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram067.pkl
# [=================================================                       ]  69%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram068.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram069.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram070.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram071.pkl
# [=====================================================                   ]  74%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram072.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram073.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram074.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram075.pkl
# [========================================================                ]  78%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram076.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram077.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram078.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram079.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram080.pkl
# [===========================================================             ]  83%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram081.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram082.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram083.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram084.pkl
# [==============================================================          ]  87%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram085.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram086.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram087.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram088.pkl
# [================================================================        ]  90%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram089.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram090.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram091.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram092.pkl
# [===================================================================     ]  94%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram093.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram094.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram095.pkl
# [======================================================================  ]  98%
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram096.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram097.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram098.pkl
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram099.pkl
# [======================================================================= ]  99%

# %%
k = 1
spec_dir = "/Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017"
file_path = spec_dir + f"/spectrogram{k:03}.pkl"
print(file_path)
# Out:
# /Volumes/John's Passport/Spectrograms/Eastern_Caldera/2017/spectrogram001.pkl

# %% [markdown]
# # Generate PSD for Different Time Windows

# %%
#Find Index for Desired Time Window
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

time1 = datetime.datetime(2017,3,15,0,0,0)
time2 = datetime.datetime(2017,3,16,0,0,0)

idx1 = find_nearest(spec_full.time, time1)
idx2 = find_nearest(spec_full.time, time2)

# %%
psd = np.mean(spec_full.values[idx1:idx2,:],axis=0)
sns.set()

fig = plt.figure(figsize=(10,7))
plt.plot(spec_full.freq, psd, linewidth=2)
plt.title(f'PSD Between {time1} and {time2}', fontsize=18)
plt.ylabel('Magnitude [dB re 1µ$Pa^2$ / H]', fontsize=14)
plt.xlabel('Frequency [Hz]', fontsize=14)
plt.savefig('psd_for_3-15to3-16.png')

# %% [markdown]
# # Learning What Happens with Partial Data

# %%
file_path = f'LJ01C-Spectrogram/spectrogram058.pkl'

with open(file_path, 'rb') as f:
    spec = pickle.load(f)
    
if(spec.values.shape[0]==60):
    a = numpy.empty((60,2049))
    a[:] = numpy.nan
    
    values = np.vstack((values,a))
    time

# %%
file_path = f'LJ01C-Spectrogram/spectrogram059.pkl'

with open(file_path, 'rb') as f:
    spec = pickle.load(f)
    
print(spec)

# %% [markdown]
# ## High Resolution Spectograms

# %%
# Get Audio
start_time = datetime.datetime(2017,3,23,0,0,0)
end_time = datetime.datetime(2017,3,23,9,0,0)
node = 'Central_Caldera'
data = hydrophone_request.get_acoustic_data_LF(start_time, end_time, node, verbose=True)
# Out:
# Downloading mseed file...

# %%
data.stats
# Out:
#          network: OO
#          station: AXCC1
#         location: Central_Caldera
#          channel: HDH
#        starttime: 2017-03-23T00:00:00.000000Z
#          endtime: 2017-03-23T01:17:34.845355Z
#    sampling_rate: 199.9999847412109
#            delta: 0.005000000381469756
#             npts: 930970
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'M', 'number_of_records': 2732, 'encoding': 'STEIM2', 'byteorder': '>', 'record_length': 512, 'filesize': 10817024})

# %%
spec = data.compute_spectrogram(L=256)

# %%
spec.visualize(xlabel_rot=30,res_reduction_time=50, fmax=100, filename='full_500hrs_Eastern_Caldera.png',save_spec=False, time_limits=None)

# %% [markdown]
# ## High Resolution Spectrogram Take 2

# %%
import progressbar
bar = progressbar.ProgressBar(maxval=500, \
    widgets=[progressbar.Bar('=', '[', ']'), ' ', progressbar.Percentage()])
bar.start()

time = []
for k in range(300,350):
    file_path = f'Central_Caldera/spectrogram{k:03}.pkl'
    try:
        with open(file_path, 'rb') as f:
            spec = pickle.load(f)
    except:
        #values_NaN = np.empty((60,2049))
        #values_NaN[:] = np.nan
        #time_NaN = np.empty(60)
        #time_NaN[:] = np.nan
        #values = np.vstack((values,values_NaN))
        #times = np.hstack((times,time_NaN))
        continue
    if spec == None:
        #values_NaN = np.empty((60,2049))
        #values_NaN[:] = np.nan
        #time_NaN = np.empty(60)
        #time_NaN[:] = np.nan
        #values = np.vstack((values,values_NaN))
        #times = np.hstack((times,time_NaN))
        continue
    
    time_UTC = spec.time
    if k == 0:
        freq = spec.freq
    for n in range(len(time_UTC)):
        if n == 0:
            time = [time_UTC[n].datetime]
        else:
            time.append(time_UTC[n].datetime)
    if k == 0:
        values = spec.values
        times = np.asarray(time)
    else:
        values = np.vstack((values,spec.values))
        times = np.hstack((times,np.asarray(time)))
    bar.update(k)
# Out:
# [=================================================                       ]  69%

# %%
# Out:
# array([[ 56.05798202,  52.08164035,  51.41647487, ...,
#          13.34849796,  10.94777528,   2.4850945 ],
#        [ 62.57858496,  59.14174477,  50.71498278, ...,
#           6.31988475,  11.81859133,   6.74168383],
#        [ 47.34670067,  46.9082794 ,  51.35060834, ...,
#           6.81856535,   7.61090715,   6.70290996],
#        ...,
#        [ 51.93172803,  47.48324053,  56.16928405, ...,
#           8.5159125 ,   8.23861247,   4.93267315],
#        [ 49.83328222,  46.105418  ,  47.77667406, ...,
#          11.50358017,   7.70447567,   8.15303727],
#        [ 55.23547259,  51.79187836,  51.6511275 , ...,
#          11.68184563,   8.37725211,   2.6749451 ]])

# %% [markdown]
# ## Looking at Energy vs. Time

# %%
import progressbar
spec_start = 0
spec_end = 600


bar = progressbar.ProgressBar(maxval=spec_end-spec_start, \
    widgets=[progressbar.Bar('=', '[', ']'), ' ', progressbar.Percentage()])
bar.start()

time = []
for k in range(spec_start,spec_end):
    file_path = f'Central_Caldera_July/spectrogram{k:03}.pkl'
    try:
        with open(file_path, 'rb') as f:
            spec = pickle.load(f)
    except:

        continue
    
    time_UTC = spec.time

    if k == spec_start:
        freq = spec.freq
    for n in range(len(time_UTC)):
        if n == 0:
            if type(time_UTC[n]) == datetime.datetime:
                time = [time_UTC[n]]
            else:
                time = [time_UTC[n].datetime]
        else:
            if type(time_UTC[n]) == datetime.datetime:
                time.append(time_UTC[n])
            else:
                time.append(time_UTC[n].datetime)
    if k == spec_start:
        values = spec.values
        times = np.asarray(time)
    else:
        values = np.vstack((values,spec.values))
        times = np.hstack((times,np.asarray(time)))
    bar.update(k- spec_start)
# Out:
# [======================================================================= ]  98%

# %%
energy = np.sum(values,axis=1)
times.shape
# Out:
# (35621,)

# %%
plt.plot(times, energy)
