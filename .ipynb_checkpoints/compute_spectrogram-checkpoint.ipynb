# %%
import os
import sys
cwd = os.getcwd()
ooipy_dir = os.path.dirname(cwd) + '/ooipy'
sys.path.append(ooipy_dir)
from matplotlib import pyplot as plt
import datetime
import numpy as np
from obspy import read,Stream, Trace
from obspy.core import UTCDateTime

from obspy import read
import pickle
import scipy
from gwpy.timeseries import TimeSeries
import seaborn as sns

from ooipy.request import hydrophone_request
from ooipy.hydrophone import basic
import gwpy

import plotly.express as px
import progressbar
from scipy import signal


# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Acquire 5 Minutes of data

start_time = datetime.datetime(2017,3,19,11,0,0)
end_time = datetime.datetime(2017,3,19,11,1,0)
node = 'Central_Caldera'

hdata = hydrophone_request.get_acoustic_data_LF(start_time, end_time, node, verbose=True)
# Out:
# Downloading mseed file...

# %%
#Resample Data
Fs_new = 64000

num_samples_old = hdata.stats.npts
Fs_old = hdata.stats.sampling_rate

factor = Fs_new/Fs_old
npts_new = len(hdata.data)*factor

hdata.data = signal.resample(hdata.data,int(npts_new))

hdata.stats.sampling_rate = Fs_new

# %%
from ooipy.tools import ooiplotlib as ooiplt

# Create Spectrogram Object
spec = hdata.compute_spectrogram(L=256,)
spec.time
# Out:
# array([datetime.datetime(2017, 3, 19, 11, 0),
#        datetime.datetime(2017, 3, 19, 11, 0, 1, 280000),
#        datetime.datetime(2017, 3, 19, 11, 0, 2, 560000),
#        datetime.datetime(2017, 3, 19, 11, 0, 3, 840000),
#        datetime.datetime(2017, 3, 19, 11, 0, 5, 120000),
#        datetime.datetime(2017, 3, 19, 11, 0, 6, 400000),
#        datetime.datetime(2017, 3, 19, 11, 0, 7, 680000),
#        datetime.datetime(2017, 3, 19, 11, 0, 8, 960000),
#        datetime.datetime(2017, 3, 19, 11, 0, 10, 240000),
#        datetime.datetime(2017, 3, 19, 11, 0, 11, 520000),
#        datetime.datetime(2017, 3, 19, 11, 0, 12, 800000),
#        datetime.datetime(2017, 3, 19, 11, 0, 14, 80000),
#        datetime.datetime(2017, 3, 19, 11, 0, 15, 360000),
#        datetime.datetime(2017, 3, 19, 11, 0, 16, 640000),
#        datetime.datetime(2017, 3, 19, 11, 0, 17, 920000),
#        datetime.datetime(2017, 3, 19, 11, 0, 19, 200000),
#        datetime.datetime(2017, 3, 19, 11, 0, 20, 480000),
#        datetime.datetime(2017, 3, 19, 11, 0, 21, 760000),
#        datetime.datetime(2017, 3, 19, 11, 0, 23, 40000),
#        datetime.datetime(2017, 3, 19, 11, 0, 24, 320000),
#        datetime.datetime(2017, 3, 19, 11, 0, 25, 600000),
#        datetime.datetime(2017, 3, 19, 11, 0, 26, 880000),
#        datetime.datetime(2017, 3, 19, 11, 0, 28, 160000),
#        datetime.datetime(2017, 3, 19, 11, 0, 29, 440000),
#        datetime.datetime(2017, 3, 19, 11, 0, 30, 720000),
#        datetime.datetime(2017, 3, 19, 11, 0, 32),
#        datetime.datetime(2017, 3, 19, 11, 0, 33, 280000),
#        datetime.datetime(2017, 3, 19, 11, 0, 34, 560000),
#        datetime.datetime(2017, 3, 19, 11, 0, 35, 840000),
#        datetime.datetime(2017, 3, 19, 11, 0, 37, 120000),
#        datetime.datetime(2017, 3, 19, 11, 0, 38, 400000),
#        datetime.datetime(2017, 3, 19, 11, 0, 39, 680000),
#        datetime.datetime(2017, 3, 19, 11, 0, 40, 960000),
#        datetime.datetime(2017, 3, 19, 11, 0, 42, 240000),
#        datetime.datetime(2017, 3, 19, 11, 0, 43, 520000),
#        datetime.datetime(2017, 3, 19, 11, 0, 44, 800000),
#        datetime.datetime(2017, 3, 19, 11, 0, 46, 80000),
#        datetime.datetime(2017, 3, 19, 11, 0, 47, 360000),
#        datetime.datetime(2017, 3, 19, 11, 0, 48, 640000),
#        datetime.datetime(2017, 3, 19, 11, 0, 49, 920000),
#        datetime.datetime(2017, 3, 19, 11, 0, 51, 200000),
#        datetime.datetime(2017, 3, 19, 11, 0, 52, 480000),
#        datetime.datetime(2017, 3, 19, 11, 0, 53, 760000),
#        datetime.datetime(2017, 3, 19, 11, 0, 55, 40000),
#        datetime.datetime(2017, 3, 19, 11, 0, 56, 320000),
#        datetime.datetime(2017, 3, 19, 11, 0, 57, 600000),
#        datetime.datetime(2017, 3, 19, 11, 0, 58, 880000),
#        datetime.datetime(2017, 3, 19, 11, 1, 0, 160000),
#        datetime.datetime(2017, 3, 19, 11, 1, 1, 440000),
#        datetime.datetime(2017, 3, 19, 11, 1, 2, 720000),
#        datetime.datetime(2017, 3, 19, 11, 1, 4),
#        datetime.datetime(2017, 3, 19, 11, 1, 5, 280000),
#        datetime.datetime(2017, 3, 19, 11, 1, 6, 560000),
#        datetime.datetime(2017, 3, 19, 11, 1, 7, 840000),
#        datetime.datetime(2017, 3, 19, 11, 1, 9, 120000),
#        datetime.datetime(2017, 3, 19, 11, 1, 10, 400000),
#        datetime.datetime(2017, 3, 19, 11, 1, 11, 680000),
#        datetime.datetime(2017, 3, 19, 11, 1, 12, 960000),
#        datetime.datetime(2017, 3, 19, 11, 1, 14, 240000),
#        datetime.datetime(2017, 3, 19, 11, 1, 15, 520000),
#        datetime.datetime(2017, 3, 19, 11, 1, 16, 800000),
#        datetime.datetime(2017, 3, 19, 11, 1, 18, 80000),
#        datetime.datetime(2017, 3, 19, 11, 1, 19, 360000),
#        datetime.datetime(2017, 3, 19, 11, 1, 20, 640000),
#        datetime.datetime(2017, 3, 19, 11, 1, 21, 920000),
#        datetime.datetime(2017, 3, 19, 11, 1, 23, 200000),
#        datetime.datetime(2017, 3, 19, 11, 1, 24, 480000),
#        datetime.datetime(2017, 3, 19, 11, 1, 25, 760000),
#        datetime.datetime(2017, 3, 19, 11, 1, 27, 40000),
#        datetime.datetime(2017, 3, 19, 11, 1, 28, 320000),
#        datetime.datetime(2017, 3, 19, 11, 1, 29, 600000),
#        datetime.datetime(2017, 3, 19, 11, 1, 30, 880000),
#        datetime.datetime(2017, 3, 19, 11, 1, 32, 160000),
#        datetime.datetime(2017, 3, 19, 11, 1, 33, 440000),
#        datetime.datetime(2017, 3, 19, 11, 1, 34, 720000),
#        datetime.datetime(2017, 3, 19, 11, 1, 36),
#        datetime.datetime(2017, 3, 19, 11, 1, 37, 280000),
#        datetime.datetime(2017, 3, 19, 11, 1, 38, 560000),
#        datetime.datetime(2017, 3, 19, 11, 1, 39, 840000),
#        datetime.datetime(2017, 3, 19, 11, 1, 41, 120000),
#        datetime.datetime(2017, 3, 19, 11, 1, 42, 400000),
#        datetime.datetime(2017, 3, 19, 11, 1, 43, 680000),
#        datetime.datetime(2017, 3, 19, 11, 1, 44, 960000),
#        datetime.datetime(2017, 3, 19, 11, 1, 46, 240000),
#        datetime.datetime(2017, 3, 19, 11, 1, 47, 520000),
#        datetime.datetime(2017, 3, 19, 11, 1, 48, 800000),
#        datetime.datetime(2017, 3, 19, 11, 1, 50, 80000),
#        datetime.datetime(2017, 3, 19, 11, 1, 51, 360000),
#        datetime.datetime(2017, 3, 19, 11, 1, 52, 640000),
#        datetime.datetime(2017, 3, 19, 11, 1, 53, 920000),
#        datetime.datetime(2017, 3, 19, 11, 1, 55, 200000),
#        datetime.datetime(2017, 3, 19, 11, 1, 56, 480000)], dtype=object)

# %%
# Create Spectrogram Object
spec = hdata.compute_spectrogram(L=512, overlap=100)
spec.visualize(fmax=100, vmax=100, res_reduction_time=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-75693fa3b5ec> in <module>
#       1 # Create Spectrogram Object
#       2 spec = hdata.compute_spectrogram(L=512, overlap=100)
# ----> 3 spec.visualize(fmax=100, vmax=100, res_reduction_time=1)
#
# ~/UW/Ocean_Acoustics/Code/ooipy/ooipy/hydrophone/basic.py in visualize(self, plot_spec, save_spec, filename, title, xlabel, xlabel_rot, ylabel, fmin, fmax, vmin, vmax, vdelta, vdelta_cbar, figsize, dpi, res_reduction_time, res_reduction_freq, time_limits)
#     683         im = ax.contourf(t, f, np.transpose(v), cbarticks,
#     684                          norm=colors.Normalize(vmin=vmin, vmax=vmax),
# --> 685                          cmap=plt.cm.jet)
#     686         plt.ylabel(ylabel)
#     687         plt.xlabel(xlabel)
#
# ~/opt/anaconda3/envs/ooi/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/envs/ooi/lib/python3.7/site-packages/matplotlib/axes/_axes.py in contourf(self, *args, **kwargs)
#    6332     def contourf(self, *args, **kwargs):
#    6333         kwargs['filled'] = True
# -> 6334         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6335         self._request_autoscale_view()
#    6336         return contours
#
# ~/opt/anaconda3/envs/ooi/lib/python3.7/site-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, *args, **kwargs)
#     820         self._transform = kwargs.pop('transform', None)
#     821
# --> 822         kwargs = self._process_args(*args, **kwargs)
#     823         self._process_levels()
#     824
#
# ~/opt/anaconda3/envs/ooi/lib/python3.7/site-packages/matplotlib/contour.py in _process_args(self, *args, **kwargs)
#    1417                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1418
# -> 1419             x, y, z = self._contour_args(args, kwargs)
#    1420
#    1421             _mask = ma.getmask(z)
#
# ~/opt/anaconda3/envs/ooi/lib/python3.7/site-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1475             args = args[1:]
#    1476         elif Nargs <= 4:
# -> 1477             x, y, z = self._check_xyz(args[:3], kwargs)
#    1478             args = args[3:]
#    1479         else:
#
# ~/opt/anaconda3/envs/ooi/lib/python3.7/site-packages/matplotlib/contour.py in _check_xyz(self, args, kwargs)
#    1508             raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1509         if z.shape[0] < 2 or z.shape[1] < 2:
# -> 1510             raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#    1511                             f"but has shape {z.shape}")
#    1512         Ny, Nx = z.shape
#
# TypeError: Input z must be at least a (2, 2) shaped array, but has shape (257, 1)

# %%
from ooipy.tools import ooiplotlib as ooiplt

spec = hdata.compute_spectrogram(L=256)
spec.visualize(xlabel_rot=30,res_reduction_time=100, fmax=100, filename='Eastern_Caldera_July.png',save_spec=False, time_limits=xlim, vmax=100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-6245f8998d8a> in <module>
#       2
#       3 spec = hdata.compute_spectrogram(L=256)
# ----> 4 spec.visualize(xlabel_rot=30,res_reduction_time=100, fmax=100, filename='Eastern_Caldera_July.png',save_spec=False, time_limits=xlim, vmax=100)
#
# ~/University-of-Washington/Ocean_Acoustics/Code/ooipy/ooipy/hydrophone/basic.py in visualize(self, plot_spec, save_spec, filename, title, xlabel, xlabel_rot, ylabel, fmin, fmax, vmin, vmax, vdelta, vdelta_cbar, figsize, dpi, res_reduction_time, res_reduction_freq, time_limits)
#     681         im = ax.contourf(t, f, np.transpose(v), cbarticks,
#     682                          norm=colors.Normalize(vmin=vmin, vmax=vmax),
# --> 683                          cmap=plt.cm.jet)
#     684         plt.ylabel(ylabel)
#     685         plt.xlabel(xlabel)
#
# ~/opt/anaconda3/envs/ooi/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/envs/ooi/lib/python3.7/site-packages/matplotlib/axes/_axes.py in contourf(self, *args, **kwargs)
#    6332     def contourf(self, *args, **kwargs):
#    6333         kwargs['filled'] = True
# -> 6334         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6335         self._request_autoscale_view()
#    6336         return contours
#
# ~/opt/anaconda3/envs/ooi/lib/python3.7/site-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, *args, **kwargs)
#     820         self._transform = kwargs.pop('transform', None)
#     821
# --> 822         kwargs = self._process_args(*args, **kwargs)
#     823         self._process_levels()
#     824
#
# ~/opt/anaconda3/envs/ooi/lib/python3.7/site-packages/matplotlib/contour.py in _process_args(self, *args, **kwargs)
#    1417                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1418
# -> 1419             x, y, z = self._contour_args(args, kwargs)
#    1420
#    1421             _mask = ma.getmask(z)
#
# ~/opt/anaconda3/envs/ooi/lib/python3.7/site-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1475             args = args[1:]
#    1476         elif Nargs <= 4:
# -> 1477             x, y, z = self._check_xyz(args[:3], kwargs)
#    1478             args = args[3:]
#    1479         else:
#
# ~/opt/anaconda3/envs/ooi/lib/python3.7/site-packages/matplotlib/contour.py in _check_xyz(self, args, kwargs)
#    1508             raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1509         if z.shape[0] < 2 or z.shape[1] < 2:
# -> 1510             raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#    1511                             f"but has shape {z.shape}")
#    1512         Ny, Nx = z.shape
#
# TypeError: Input z must be at least a (2, 2) shaped array, but has shape (129, 1)

# %%
spec

# %% [markdown]
# # Merging All Spectrograms

# %%
import progressbar
spec_start = 0
spec_end = 600


bar = progressbar.ProgressBar(maxval=spec_end-spec_start, \
    widgets=[progressbar.Bar('=', '[', ']'), ' ', progressbar.Percentage()])
bar.start()

time = []
for k in range(spec_start,spec_end):
    file_path = f'Axial_Base_July/spectrogram{k:03}.pkl'
    print(file_path)
    try:
        with open(file_path, 'rb') as f:
            spec = pickle.load(f)
    except:

        continue
    
    time_UTC = spec.time
    
    print(time)
    if k == spec_start:
        freq = spec.freq
    for n in range(len(time_UTC)):
        if n == 0:
            time = [time_UTC[n].datetime]
        else:
            time.append(time_UTC[n].datetime)
    if k == spec_start:
        values = spec.values
        times = np.asarray(time)
    else:
        values = np.vstack((values,spec.values))
        times = np.hstack((times,np.asarray(time)))
    bar.update(k- spec_start)
# Out:
# [                                                                        ] N/A%
# []
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-4d1d442829b3> in <module>
#      25     for n in range(len(time_UTC)):
#      26         if n == 0:
# ---> 27             time = [time_UTC[n].datetime]
#      28         else:
#      29             time.append(time_UTC[n].datetime)
#
# AttributeError: 'datetime.datetime' object has no attribute 'datetime'

# %%
print(values.shape)
print(times.shape)
print(freq.shape)
# Out:
# (27674, 2049)
# (27674,)
# (2049,)

# %%
# Generate alternate time variables
from datetime import timedelta

times_delta = []
times_new = np.zeros((len(times),1))
for k in range(len(times)):
    times_delta.append(times[k]-times[0])
    
    times_new[k] = times_delta[k].days*24 + times_delta[k].seconds/3600


times_new = np.squeeze(times_new)

print(np.shape(times_new))
# Out:
# (35621,)

# %%
plt.imshow(values.T)

# %%
# Create Spectrogram Object

spec_full = basic.Spectrogram(times, freq, values)

# %%
#fig = px.imshow(values.T, origin='lower', x=times, y=freq, labels = {'color':'dB re 1µ Pa^2/Hz'})
xlim = [datetime.datetime(2017,7,13,18,0,0), datetime.datetime(2017,7,14,12,0,0)]
spec_full.visualize(xlabel_rot=30,res_reduction_time=300, fmax=100, filename='Central_Caldera_March_80.png',save_spec=False, time_limits=xlim, vmax=80)

# %% [markdown]
# # Generate PSD for Different Time Windows

# %%
#Find Index for Desired Time Window
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

time1 = datetime.datetime(2017,3,15,0,0,0)
time2 = datetime.datetime(2017,3,16,0,0,0)

idx1 = find_nearest(spec_full.time, time1)
idx2 = find_nearest(spec_full.time, time2)

# %%
psd = np.mean(spec_full.values[idx1:idx2,:],axis=0)
sns.set()

fig = plt.figure(figsize=(10,7))
plt.plot(spec_full.freq, psd, linewidth=2)
plt.title(f'PSD Between {time1} and {time2}', fontsize=18)
plt.ylabel('Magnitude [dB re 1µ$Pa^2$ / H]', fontsize=14)
plt.xlabel('Frequency [Hz]', fontsize=14)
plt.savefig('psd_for_3-15to3-16.png')

# %% [markdown]
# # Learning What Happens with Partial Data

# %%
file_path = f'LJ01C-Spectrogram/spectrogram058.pkl'

with open(file_path, 'rb') as f:
    spec = pickle.load(f)
    
if(spec.values.shape[0]==60):
    a = numpy.empty((60,2049))
    a[:] = numpy.nan
    
    values = np.vstack((values,a))
    time

# %%
file_path = f'LJ01C-Spectrogram/spectrogram059.pkl'

with open(file_path, 'rb') as f:
    spec = pickle.load(f)
    
print(spec)

# %% [markdown]
# ## High Resolution Spectograms

# %%
# Get Audio
start_time = datetime.datetime(2017,3,23,0,0,0)
end_time = datetime.datetime(2017,3,23,9,0,0)
node = 'Central_Caldera'
data = hydrophone_request.get_acoustic_data_LF(start_time, end_time, node, verbose=True)
# Out:
# Downloading mseed file...

# %%
data.stats
# Out:
#          network: OO
#          station: AXCC1
#         location: Central_Caldera
#          channel: HDH
#        starttime: 2017-03-23T00:00:00.000000Z
#          endtime: 2017-03-23T01:17:34.845355Z
#    sampling_rate: 199.9999847412109
#            delta: 0.005000000381469756
#             npts: 930970
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'M', 'number_of_records': 2732, 'encoding': 'STEIM2', 'byteorder': '>', 'record_length': 512, 'filesize': 10817024})

# %%
spec = data.compute_spectrogram(L=256)

# %%
spec.visualize(xlabel_rot=30,res_reduction_time=50, fmax=100, filename='full_500hrs_Eastern_Caldera.png',save_spec=False, time_limits=None)

# %% [markdown]
# ## High Resolution Spectrogram Take 2

# %%
import progressbar
bar = progressbar.ProgressBar(maxval=500, \
    widgets=[progressbar.Bar('=', '[', ']'), ' ', progressbar.Percentage()])
bar.start()

time = []
for k in range(300,350):
    file_path = f'Central_Caldera/spectrogram{k:03}.pkl'
    try:
        with open(file_path, 'rb') as f:
            spec = pickle.load(f)
    except:
        #values_NaN = np.empty((60,2049))
        #values_NaN[:] = np.nan
        #time_NaN = np.empty(60)
        #time_NaN[:] = np.nan
        #values = np.vstack((values,values_NaN))
        #times = np.hstack((times,time_NaN))
        continue
    if spec == None:
        #values_NaN = np.empty((60,2049))
        #values_NaN[:] = np.nan
        #time_NaN = np.empty(60)
        #time_NaN[:] = np.nan
        #values = np.vstack((values,values_NaN))
        #times = np.hstack((times,time_NaN))
        continue
    
    time_UTC = spec.time
    if k == 0:
        freq = spec.freq
    for n in range(len(time_UTC)):
        if n == 0:
            time = [time_UTC[n].datetime]
        else:
            time.append(time_UTC[n].datetime)
    if k == 0:
        values = spec.values
        times = np.asarray(time)
    else:
        values = np.vstack((values,spec.values))
        times = np.hstack((times,np.asarray(time)))
    bar.update(k)
# Out:
# [=================================================                       ]  69%

# %%
# Out:
# array([[ 56.05798202,  52.08164035,  51.41647487, ...,
#          13.34849796,  10.94777528,   2.4850945 ],
#        [ 62.57858496,  59.14174477,  50.71498278, ...,
#           6.31988475,  11.81859133,   6.74168383],
#        [ 47.34670067,  46.9082794 ,  51.35060834, ...,
#           6.81856535,   7.61090715,   6.70290996],
#        ...,
#        [ 51.93172803,  47.48324053,  56.16928405, ...,
#           8.5159125 ,   8.23861247,   4.93267315],
#        [ 49.83328222,  46.105418  ,  47.77667406, ...,
#          11.50358017,   7.70447567,   8.15303727],
#        [ 55.23547259,  51.79187836,  51.6511275 , ...,
#          11.68184563,   8.37725211,   2.6749451 ]])
