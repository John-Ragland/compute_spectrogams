# %%
import os
import sys
cwd = os.getcwd()
ooipy_dir = os.path.dirname(cwd) + '/ooipy'
sys.path.append(ooipy_dir)
from matplotlib import pyplot as plt
import datetime
import numpy as np
from obspy import read,Stream, Trace
from obspy.core import UTCDateTime

from obspy import read
import pickle
import scipy
from gwpy.timeseries import TimeSeries
import seaborn as sns

from ooipy.request import hydrophone_request
from ooipy.hydrophone import basic
import gwpy

import plotly.express as px


# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
# Acquire 5 Minutes of data

start_time = datetime.datetime(2017,3,10,0,0,0)
end_time = datetime.datetime(2017,3,10,0,5,0)
node = '/LJ01C'

hdata = hydrophone_request.get_acoustic_data(start_time, end_time, node, verbose=True)
# Out:
# Fetching URLs...
# Sorting valid URLs for Time Window...
# Downloading mseed files...
# Other exception

# %%
# Save data to MATLAB file
nparray = hdata.data

mdic = {"hdata": nparray}
scipy.io.savemat('5min_data.mat', mdic)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-9941b5610cf3> in <module>
#       1 # Save data to MATLAB file
# ----> 2 nparray = hdata.data
#       3
#       4 mdic = {"hdata": nparray}
#       5 scipy.io.savemat('5min_data.mat', mdic)
#
# AttributeError: 'NoneType' object has no attribute 'data'

# %%
print(hdata.stats)

# %%
spec = hdata.compute_spectrogram_mp(avg_time=60)

# %%
spec.visualize(fmax=25000, xlabel_rot=30)

# %%
# Write to Pickle File
filename = 'spectrogram3.pkl'
with open(filename,'wb') as f:
    pickle.dump(spec, f)

# %%
print(gwpy.time.to_gps(hdata.stats.starttime))

# %% [markdown]
# # Merging All Spectrograms

# %%
time = []
for k in range(500):
    file_path = f'Central_Caldera/spectrogram{k:03}.pkl'
    try:
        with open(file_path, 'rb') as f:
            spec = pickle.load(f)
    except:
        #values_NaN = np.empty((60,2049))
        #values_NaN[:] = np.nan
        #time_NaN = np.empty(60)
        #time_NaN[:] = np.nan
        #values = np.vstack((values,values_NaN))
        #times = np.hstack((times,time_NaN))
        continue
    if spec == None:
        #values_NaN = np.empty((60,2049))
        #values_NaN[:] = np.nan
        #time_NaN = np.empty(60)
        #time_NaN[:] = np.nan
        #values = np.vstack((values,values_NaN))
        #times = np.hstack((times,time_NaN))
        continue
    
    time_UTC = spec.time
    if k == 0:
        freq = spec.freq
    for n in range(len(time_UTC)):
        if n == 0:
            time = [time_UTC[n].datetime]
        else:
            time.append(time_UTC[n].datetime)
    if k == 0:
        values = spec.values
        times = np.asarray(time)
    else:
        values = np.vstack((values,spec.values))
        times = np.hstack((times,np.asarray(time)))

# %%
print(values.shape)
print(times.shape)
print(freq.shape)
# Out:
# (17568, 2049)
# (17568,)
# (2049,)

# %%
# Remove all NaN
plt.imshow(values.T)

# %%
# Create Spectrogram Object

spec_full = basic.Spectrogram(times, freq, values)

# %%
#fig = px.imshow(values.T, origin='lower', x=times, y=freq, labels = {'color':'dB re 1µ Pa^2/Hz'})
xlim = [datetime.datetime(2017,3,15,0,0,0), datetime.datetime(2017,3,16,0,0,0)]

spec_full.visualize(xlabel_rot=30,res_reduction_time=50, fmax=25000, filename='full_15_spectrogram.png',save_spec=False, time_limits=xlim)

# %% [markdown]
# # Generate PSD for Different Time Windows

# %%
#Find Index for Desired Time Window
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

time1 = datetime.datetime(2017,3,15,0,0,0)
time2 = datetime.datetime(2017,3,16,0,0,0)

idx1 = find_nearest(spec_full.time, time1)
idx2 = find_nearest(spec_full.time, time2)

# %%
psd = np.mean(spec_full.values[idx1:idx2,:],axis=0)
sns.set()

fig = plt.figure(figsize=(10,7))
plt.plot(spec_full.freq, psd, linewidth=2)
plt.title(f'PSD Between {time1} and {time2}', fontsize=18)
plt.ylabel('Magnitude [dB re 1µ$Pa^2$ / H]', fontsize=14)
plt.xlabel('Frequency [Hz]', fontsize=14)
plt.savefig('psd_for_3-15to3-16.png')

# %% [markdown]
# # Learning What Happens with Partial Data

# %%
file_path = f'LJ01C-Spectrogram/spectrogram058.pkl'

with open(file_path, 'rb') as f:
    spec = pickle.load(f)
    
if(spec.values.shape[0]==60):
    a = numpy.empty((60,2049))
    a[:] = numpy.nan
    
    values = np.vstack((values,a))
    time

# %%
file_path = f'LJ01C-Spectrogram/spectrogram059.pkl'

with open(file_path, 'rb') as f:
    spec = pickle.load(f)
    
print(spec)
