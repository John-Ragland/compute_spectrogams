# %%
import pickle
import ooipy
import spec_tools
import numpy as np
from matplotlib import pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %%
spec_dir = '/Volumes/Ocean_Acoustics/Spectrograms/Axial_Base/2018/'

time, freq, values = spec_tools.merge(8730,8750,spec_dir, verbose=False)
spec = ooipy.hydrophone.basic.Spectrogram(time, freq, values)

# %%
downsample = np.mean(values, axis=0)
date = time[0]

# %%
print(downsample)
print(date)
# Out:
# [ 64.57630297  60.62503221  70.17788766 ...,  21.15244708
#   21.24222887  16.63009241]
# 2018-12-30 18:00:00

# %%
plt.plot(freq, downsample)

# %%
for k in range(0,8759,12):
    start = k
    end = k + 11
    print(start, end)
# Out:
# 0 11
# 12 23
# 24 35
# 36 47
# 48 59
# 60 71
# 72 83
# 84 95
# 96 107
# 108 119
# 120 131
# 132 143
# 144 155
# 156 167
# 168 179
# 180 191
# 192 203
# 204 215
# 216 227
# 228 239
# 240 251
# 252 263
# 264 275
# 276 287
# 288 299
# 300 311
# 312 323
# 324 335
# 336 347
# 348 359
# 360 371
# 372 383
# 384 395
# 396 407
# 408 419
# 420 431
# 432 443
# 444 455
# 456 467
# 468 479
# 480 491
# 492 503
# 504 515
# 516 527
# 528 539
# 540 551
# 552 563
# 564 575
# 576 587
# 588 599
# 600 611
# 612 623
# 624 635
# 636 647
# 648 659
# 660 671
# 672 683
# 684 695
# 696 707
# 708 719
# 720 731
# 732 743
# 744 755
# 756 767
# 768 779
# 780 791
# 792 803
# 804 815
# 816 827
# 828 839
# 840 851
# 852 863
# 864 875
# 876 887
# 888 899
# 900 911
# 912 923
# 924 935
# 936 947
# 948 959
# 960 971
# 972 983
# 984 995
# 996 1007
# 1008 1019
# 1020 1031
# 1032 1043
# 1044 1055
# 1056 1067
# 1068 1079
# 1080 1091
# 1092 1103
# 1104 1115
# 1116 1127
# 1128 1139
# 1140 1151
# 1152 1163
# 1164 1175
# ...

# %%
time, freq, values = spec_tools.downsample_for_figure('Eastern_Caldera')
# Out:
# 0.35679

# %%
values.shape
# Out:
# (14, 2049)
